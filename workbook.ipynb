# %%
from acquire import get_telco_data
from prepare import prep_telco

# %%
from explore import train_validate_test_split

# %%
df = get_telco_data()
df
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
# ...

# %%
df = prep_telco(df)

# %%
df
# Out:
#       partner  dependents  phone_service  multiple_lines  online_security  \
# 0           1           1              1               0                0
# 1           0           0              1               1                0
# 2           0           0              1               0                0
# 3           1           0              1               0                0
# 4           1           0              1               0                0
# ...       ...         ...            ...             ...              ...
# 7038        0           0              1               0                1
# 7039        1           0              1               1                0
# 7040        0           0              1               0                0
# 7041        1           1              1               0                1
# 7042        1           1              0               0                1
#
#       online_backup  device_protection  tech_support  streaming_tv  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   partner                                 7043 non-null   int64
#  1   dependents                              7043 non-null   int64
#  2   phone_service                           7043 non-null   int64
#  3   multiple_lines                          7043 non-null   int64
#  4   online_security                         7043 non-null   int64
#  5   online_backup                           7043 non-null   int64
#  6   device_protection                       7043 non-null   int64
#  7   tech_support                            7043 non-null   int64
#  8   streaming_tv                            7043 non-null   int64
#  9   streaming_movies                        7043 non-null   int64
# ...

# %%
train, validate, test = train_validate_test_split(df, target = 'churn')

# %%
train.shape, validate.shape, test.shape
# Out:
# ((3943, 28), (1691, 28), (1409, 28))

# %%
churn_rate = train.churn.mean()
churn_rate
# Out:
# 0.2652802434694395

# %%
import matplotlib.pyplot as plt

# %%
train.churn.value_counts()
# plt.plot.bar(train.churn)
# Out:
# 0    2897
# 1    1046
# Name: churn, dtype: int64

# %%
corr = train.corr()

# %%
corr['churn'].sort_values()
# Out:
# tenure                                   -0.346061
# contract_type_Two year                   -0.293097
# internet_service_type_None               -0.222525
# total_charges                            -0.191637
# contract_type_One year                   -0.180598
# dependents                               -0.167771
# online_security                          -0.158750
# partner                                  -0.158691
# tech_support                             -0.150712
# payment_type_Bank transfer (automatic)   -0.133641
# payment_type_Credit card (automatic)     -0.126973
# internet_service_type_DSL                -0.125764
# online_backup                            -0.088072
# payment_type_Mailed check                -0.078254
# device_protection                        -0.068312
# is_male                                   0.000669
# phone_service                             0.009568
# multiple_lines                            0.033437
# ...

# %%
import explore

# %%
cat_vars = ['partner', 'dependents', 'phone_service', 'multiple_lines',
            'online_security', 'online_backup', 'device_protection', 
            'tech_support', 'streaming_tv', 
            'streaming_movies', 'paperless_billing','is_male', 'senior_citizen', 'contract_type_Month-to-month',           
            'contract_type_One year','contract_type_Two year', 'internet_service_type_DSL','internet_service_type_Fiber optic',     
            'internet_service_type_None', 'payment_type_Bank transfer (automatic)', 'payment_type_Credit card (automatic)',  
            'payment_type_Electronic check', 'payment_type_Mailed check']

quant_vars = ['tenure', 'monthly_charges', 'total_charges']
target = 'churn'

# %%
explore.explore_univariate(train, cat_vars, quant_vars )
# Out:
#    partner  Count  Percent
# 0        1   2024    51.33
# 1        0   1919    48.67
# _________________________________________________________________
#    dependents  Count  Percent
# 0           0   2730    69.24
# 1           1   1213    30.76
# _________________________________________________________________
#    phone_service  Count  Percent
# 1              1   3578    90.74
# 0              0    365     9.26
# _________________________________________________________________
#    multiple_lines  Count  Percent
# 0               1   2246    56.96
# 1               0   1697    43.04
# _________________________________________________________________
#    online_security  Count  Percent
# 0                1   2795    70.89
# 1                0   1148    29.11
# _________________________________________________________________
#    online_backup  Count  Percent
# 0              1   2551     64.7
# 1              0   1392     35.3
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
explore.explore_bivariate(train, 'churn', cat_vars, quant_vars)
# Out:
# partner
# _____________________
#
#         chi2       p-value  degrees of freedom
# 0  98.577941  3.124808e-23                   1
#
# observed:
#  churn       0     1   All
# partner
# 0        1349   675  2024
# 1        1548   371  1919
# All      2897  1046  3943
#
# expected:
#               0           1
# 0  1487.072787  536.927213
# 1  1409.927213  509.072787
# _____________________
#
# dependents
# _____________________
#
#          chi2       p-value  degrees of freedom
# 0  110.161868  9.030713e-26                   1
#
# observed:
#  churn          0     1   All
# dependents
# 0           1871   859  2730
# 1           1026   187  1213
# All         2897  1046  3943
#
# expected:
#               0           1
# 0  2005.784935  724.215065
# 1   891.215065  321.784935
# _____________________
#
# phone_service
# _____________________
#
#        chi2   p-value  degrees of freedom
# 0  0.290067  0.590177                   1
#
# observed:
#  churn             0     1   All
# ...

# %%
import explore
import seaborn as sns

# %%
explore.explore_bivariate_quant(train, 'churn', quant_var='monthly_charges')f
# Out:
# monthly_charges
# ____________________
#         count       mean        std    min   25%     50%    75%     max
# churn
# 0      2897.0  61.897394  31.226307  18.25  25.2  65.250  89.05  118.75
# 1      1046.0  74.832935  25.081170  18.85  58.6  79.775  94.75  118.35
#
#
# Mann-Whitney Test:
#  MannwhitneyuResult(statistic=1157095.0, pvalue=7.841086672350971e-30)
#
# ____________________
